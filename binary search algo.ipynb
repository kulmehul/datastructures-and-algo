# %%
# unordered
# LS algo
cars = [3333,5555,8888,1111,9999,2222,4444,7777,6666]

# %%
len(cars)
# Out:
# 9

# %%
# sort data list/array:  sort algorithm
# sort algo
sorted_cars= sorted(cars)

# %%
# ordered : sorted
sorted_cars
# Out:
# [1111, 2222, 3333, 4444, 5555, 6666, 7777, 8888, 9999]

# %%
import math

# %%
math.log(8192,2)
# Out:
# 13.0

# %%
sorted_cars
# Out:
# [1111, 2222, 3333, 4444, 5555, 6666, 7777, 8888, 9999]

# %%
end
# Out:
# 8

# %%
sorted_cars
# Out:
# [1111, 2222, 3333, 4444, 5555, 6666, 7777, 8888, 9999]

# %%
def my_binary_search(arr , myvalue):
    start = 0
    end = len(arr) - 1
    value = myvalue
    middle = int ( ( start + end  ) / 2 )

    print(start, middle, end)

    while not(arr[middle] == value):

        if arr[middle] < value:
            print("right side")
            start = middle + 1
            middle = int ( ( start + end  ) / 2 )


        elif arr[middle] > value:
            print("left side")
            end = middle - 1
            middle = int ( ( start + end  ) / 2 )


        print(start, middle, end)


    if sorted_cars[middle] == value:
            print("found")

# %%
my_binary_search(sorted_cars , 432)
# Out:
# 0 4 8
# left side
# 0 1 3
# left side
# 0 0 0
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# ...
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0 0 -1
# left side
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-582beeef2cee> in <module>
# ----> 1 my_binary_search(sorted_cars , 432)
#
# <ipython-input-93-7df75d1e4087> in my_binary_search(arr, myvalue)
#      21
#      22
# ---> 23         print(start, middle, end)
#      24
#      25
#
# ~\anaconda3_2021_05\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\anaconda3_2021_05\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\anaconda3_2021_05\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     489                                  copy_threshold=self.copy_threshold)
#     490             data.group = group
# --> 491         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     492
#     493     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3_2021_05\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
type(middle)
# Out:
# int

# %%
middle
# Out:
# 4

# %%
sorted_cars[middle]
# Out:
# 5555

# %%
# Out:
# found
